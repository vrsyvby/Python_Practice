# %%
import pandas as pd

# %%
bond = pd.read_csv("/Users/naginilandarhi/DSAICourse/Python_Practice/Udemy/pandas/Incomplete/jamesbond.csv")

# %%
bond.head(5)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
## bond = pd.read_csv("/Users/naginilandarhi/DSAICourse/Python_Practice/Udemy/pandas/Incomplete/jamesbond.csv", index_col="Film")
## above line of code is equivalent to the one below
bond.set_index("Film", inplace=True)
##bond.set_index("Year", inplace=True)
## if we make year as the index, it will not be unique, so we cannot use it as an index
## and we will lose Film entirely, because it will be overriden by Year
bond.sort_index(inplace=True)
bond.head(5)
bond.reset_index(inplace=True)

# %%
bond.head(5)
# Out:
#                    Film  Year           Actor         Director  Box Office  \
# 0      A View to a Kill  1985     Roger Moore        John Glen       275.2
# 1         Casino Royale  2006    Daniel Craig  Martin Campbell       581.5
# 2         Casino Royale  1967     David Niven       Ken Hughes       315.0
# 3  Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# 4       Die Another Day  2002  Pierce Brosnan     Lee Tamahori       465.4
#
#    Budget  Bond Actor Salary
# 0    54.5                9.1
# 1   145.3                3.3
# 2    85.0                NaN
# 3    34.7                5.8
# 4   154.2               17.9

# %%
## To retrieve rows by their index position, we can use .iloc
bond.iloc[0:5]  # Retrieves the first 5 rows
# Out:
#                    Film  Year           Actor         Director  Box Office  \
# 0      A View to a Kill  1985     Roger Moore        John Glen       275.2
# 1         Casino Royale  2006    Daniel Craig  Martin Campbell       581.5
# 2         Casino Royale  1967     David Niven       Ken Hughes       315.0
# 3  Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# 4       Die Another Day  2002  Pierce Brosnan     Lee Tamahori       465.4
#
#    Budget  Bond Actor Salary
# 0    54.5                9.1
# 1   145.3                3.3
# 2    85.0                NaN
# 3    34.7                5.8
# 4   154.2               17.9

# %%
bond.iloc[0:5]
# Out:
#                    Film  Year           Actor         Director  Box Office  \
# 0      A View to a Kill  1985     Roger Moore        John Glen       275.2
# 1         Casino Royale  2006    Daniel Craig  Martin Campbell       581.5
# 2         Casino Royale  1967     David Niven       Ken Hughes       315.0
# 3  Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# 4       Die Another Day  2002  Pierce Brosnan     Lee Tamahori       465.4
#
#    Budget  Bond Actor Salary
# 0    54.5                9.1
# 1   145.3                3.3
# 2    85.0                NaN
# 3    34.7                5.8
# 4   154.2               17.9

# %%
bond.iloc[4:8]
# Out:
#                     Film  Year           Actor       Director  Box Office  \
# 4        Die Another Day  2002  Pierce Brosnan   Lee Tamahori       465.4
# 5                 Dr. No  1962    Sean Connery  Terence Young       448.8
# 6     For Your Eyes Only  1981     Roger Moore      John Glen       449.4
# 7  From Russia with Love  1963    Sean Connery  Terence Young       543.8
#
#    Budget  Bond Actor Salary
# 4   154.2               17.9
# 5     7.0                0.6
# 6    60.2                NaN
# 7    12.6                1.6

# %%
bond.iloc[[1,2,3,4]]
# Out:
#                    Film  Year           Actor         Director  Box Office  \
# 1         Casino Royale  2006    Daniel Craig  Martin Campbell       581.5
# 2         Casino Royale  1967     David Niven       Ken Hughes       315.0
# 3  Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# 4       Die Another Day  2002  Pierce Brosnan     Lee Tamahori       465.4
#
#    Budget  Bond Actor Salary
# 1   145.3                3.3
# 2    85.0                NaN
# 3    34.7                5.8
# 4   154.2               17.9

# %%
bond.iloc[:5]
# Out:
#                    Film  Year           Actor         Director  Box Office  \
# 0      A View to a Kill  1985     Roger Moore        John Glen       275.2
# 1         Casino Royale  2006    Daniel Craig  Martin Campbell       581.5
# 2         Casino Royale  1967     David Niven       Ken Hughes       315.0
# 3  Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# 4       Die Another Day  2002  Pierce Brosnan     Lee Tamahori       465.4
#
#    Budget  Bond Actor Salary
# 0    54.5                9.1
# 1   145.3                3.3
# 2    85.0                NaN
# 3    34.7                5.8
# 4   154.2               17.9

# %%
bond.iloc[5:]
# Out:
#                                Film  Year           Actor            Director  \
# 5                            Dr. No  1962    Sean Connery       Terence Young
# 6                For Your Eyes Only  1981     Roger Moore           John Glen
# 7             From Russia with Love  1963    Sean Connery       Terence Young
# 8                         GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 9                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 10                  Licence to Kill  1989  Timothy Dalton           John Glen
# 11                 Live and Let Die  1973     Roger Moore        Guy Hamilton
# 12                        Moonraker  1979     Roger Moore       Lewis Gilbert
# 13            Never Say Never Again  1983    Sean Connery      Irvin Kershner
# 14                   No Time to Die  2021    Daniel Craig  Cary Joji Fukunaga
# 15                        Octopussy  1983     Roger Moore           John Glen
# ...

# %%
bond.set_index("Film", inplace=True)

# %%
bond.loc["Dr. No":"Goldfinger"]  # Retrieves rows from "Dr. No" to "Goldfinger"
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# Dr. No                 1962    Sean Connery    Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore        John Glen       449.4
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
# Goldfinger             1964    Sean Connery     Guy Hamilton       820.4
#
#                        Budget  Bond Actor Salary
# Film
# Dr. No                    7.0                0.6
# For Your Eyes Only       60.2                NaN
# From Russia with Love    12.6                1.6
# GoldenEye                76.9                5.1
# Goldfinger               18.6                3.2

# %%
bond.loc["Dr. No"]
# Out:
# Year                          1962
# Actor                 Sean Connery
# Director             Terence Young
# Box Office                   448.8
# Budget                         7.0
# Bond Actor Salary              0.6
# Name: Dr. No, dtype: object

# %%
bond.loc["Goldfinger":"Dr. No"]  # This will not work as expected, as it tries to reverse the order
# bond.loc["Goldfinger":"Dr. No"]  # This will not work as expected
# It will not retrieve rows in reverse order, as loc is not designed for that
# Out:
# Empty DataFrame
# Columns: [Year, Actor, Director, Box Office, Budget, Bond Actor Salary]
# Index: []

# %%
bond.loc["Casino Royale":"Dr. No"]
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
# Dr. No                1962    Sean Connery    Terence Young       448.8
#
#                       Budget  Bond Actor Salary
# Film
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9
# Dr. No                   7.0                0.6

# %%
bond.loc[:"Casino Royale"]
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.loc["Casino Royale":]
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
bond.loc["Casino Royale":, "Year":]
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
bond.loc["Casino Royale":, "Year":"Actor"]
# Out:
#                                  Year           Actor
# Film
# Casino Royale                    2006    Daniel Craig
# Casino Royale                    1967     David Niven
# Diamonds Are Forever             1971    Sean Connery
# Die Another Day                  2002  Pierce Brosnan
# Dr. No                           1962    Sean Connery
# For Your Eyes Only               1981     Roger Moore
# From Russia with Love            1963    Sean Connery
# GoldenEye                        1995  Pierce Brosnan
# Goldfinger                       1964    Sean Connery
# Licence to Kill                  1989  Timothy Dalton
# Live and Let Die                 1973     Roger Moore
# Moonraker                        1979     Roger Moore
# Never Say Never Again            1983    Sean Connery
# No Time to Die                   2021    Daniel Craig
# Octopussy                        1983     Roger Moore
# On Her Majesty's Secret Service  1969  George Lazenby
# ...

# %%
bond.loc["Dr. No","Actor"] = "Sir Sean Connery"

# %%
bond
# Out:
#                                  Year             Actor            Director  \
# Film
# A View to a Kill                 1985       Roger Moore           John Glen
# Casino Royale                    2006      Daniel Craig     Martin Campbell
# Casino Royale                    1967       David Niven          Ken Hughes
# Diamonds Are Forever             1971      Sean Connery        Guy Hamilton
# Die Another Day                  2002    Pierce Brosnan        Lee Tamahori
# Dr. No                           1962  Sir Sean Connery       Terence Young
# For Your Eyes Only               1981       Roger Moore           John Glen
# From Russia with Love            1963      Sean Connery       Terence Young
# GoldenEye                        1995    Pierce Brosnan     Martin Campbell
# Goldfinger                       1964      Sean Connery        Guy Hamilton
# Licence to Kill                  1989    Timothy Dalton           John Glen
# ...

# %%
bond["Actor"].replace("Sir Sean Connery", "Sean Connery", inplace=True)

# %%
bond.rename(columns={"Actor": "Lead Actor"}, inplace=True)

# %%
swaps = {"GoldenEye": "Golden Eye", "Dr. No": "Dr No"}
bond.rename(index=swaps, inplace=True)

# %%
bond
# Out:
#                                  Year        Lead Actor            Director  \
# Film
# A View to a Kill                 1985       Roger Moore           John Glen
# Casino Royale                    2006      Daniel Craig     Martin Campbell
# Casino Royale                    1967       David Niven          Ken Hughes
# Diamonds Are Forever             1971  Sir Sean Connery        Guy Hamilton
# Die Another Day                  2002    Pierce Brosnan        Lee Tamahori
# Dr No                            1962  Sir Sean Connery       Terence Young
# For Your Eyes Only               1981       Roger Moore           John Glen
# From Russia with Love            1963  Sir Sean Connery       Terence Young
# Golden Eye                       1995    Pierce Brosnan     Martin Campbell
# Goldfinger                       1964  Sir Sean Connery        Guy Hamilton
# Licence to Kill                  1989    Timothy Dalton           John Glen
# ...
